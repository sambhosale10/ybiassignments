# %%
import pandas as pd

# %%
headphone = pd.read_csv('https://github.com/ybifoundation/Dataset/raw/main/Flipkart%20Headphones.csv')

# %%
headphone.head()
# Out:
#                                                Model   Company       Color  \
# 0             5PLUS 5PHP28 Wired without Mic Headset     5PLUS         Red
# 1  A R Wireless compatible with Headset Bluetooth...       A R         Red
# 2  Aerizo Wireless Touch R100 Earbuds (Black) Blu...    Aerizo       Black
# 3  Allmusic powerful driven bass with dynamic bea...  Allmusic  Multicolor
# 4  Allmusic OPP.O Ultra HD Sound Premium Bass Spo...  Allmusic       Black
#
#              Type  Average Rating  Number of Ratings  Selling Price  \
# 0      On the Ear             3.6                101            496
# 1      Multicolor             3.9              35280            188
# 2   True Wireless             4.0               1934            589
# 3      In the Ear             4.0              15841            260
# 4      In the Ear             3.8              10766            270
#
#    Maximum Retail Price  Discount
# 0                  3399      2903
# 1                   799       611
# ...

# %%
headphone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Model                 1000 non-null   object
#  1   Company               1000 non-null   object
#  2   Color                 1000 non-null   object
#  3   Type                  1000 non-null   object
#  4   Average Rating        1000 non-null   float64
#  5   Number of Ratings     1000 non-null   int64
#  6   Selling Price         1000 non-null   int64
#  7   Maximum Retail Price  1000 non-null   int64
#  8   Discount              1000 non-null   int64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 70.4+ KB

# %%
headphone.describe()
# Out:
#        Average Rating  Number of Ratings  Selling Price  Maximum Retail Price  \
# count     1000.000000       1.000000e+03    1000.000000           1000.000000
# mean         3.831000       5.004075e+04     832.875000           2423.043000
# std          0.467459       1.572297e+05     812.535141           1774.025318
# min          1.000000       0.000000e+00      88.000000              0.000000
# 25%          3.600000       1.167500e+02     349.000000           1079.750000
# 50%          3.900000       1.712000e+03     599.000000           1999.000000
# 75%          4.000000       1.332700e+04     999.000000           2999.000000
# max          5.000000       1.299042e+06    7990.000000          16999.000000
#
#            Discount
# count   1000.000000
# mean    1590.168000
# std     1341.379254
# min    -2991.000000
# 25%      697.500000
# 50%     1390.500000
# 75%     2250.000000
# max    12000.000000

# %%
headphone.columns
# Out:
# Index(['Model', 'Company', 'Color', 'Type', 'Average Rating',
#        'Number of Ratings', 'Selling Price', 'Maximum Retail Price',
#        'Discount'],
#       dtype='object')

# %%
headphone.shape
# Out:
# (1000, 9)

# %%
y= headphone['Selling Price']

# %%
x= headphone[['Model','Company','Color','Type','Average Rating','Number of Ratings','Maximum Retail Price','Discount']]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, train_size=0.5,random_state=2528)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((500, 8), (500, 8), (500,), (500,))

# %%
x_train
# Out:
#                                                  Model   Company       Color  \
# 781  Sunnybuy TWS T8 True Air_buds Wireless High Ba...  Sunnybuy       Black
# 262  Boult Audio ProBass Curve Neckband Bluetooth H...     Boult       Black
# 823  TIGENECY LOW PRICE ALL MOBILE SUPPORTED COMBO ...  TIGENECY       Black
# 229  Boult Audio AirBass ENCore with Environmental ...     Boult       Black
# 878             Ubon CL-116 Neckband Bluetooth Headset      Ubon      Yellow
# ..                                                 ...       ...         ...
# 147                   boAt BassHeads 100 Wired Headset      boAt  Taffy Pink
# 150                   boAt BassHeads 100 Wired Headset      boAt       White
# 210              Boult Audio Bass Bud Q2 Wired Headset     Boult       Black
# 665             Plus Shine i12s_MA05 Bluetooth Headset      Plus       White
# 399  FIER MAGNET-K1-I7 Pack of 3 Bluetooth Bluetoot...      FIER       Black
#
# ...

# %%
y_train
# Out:
# 781    1199
# 262     999
# 823     225
# 229    1999
# 878     489
#        ...
# 147     399
# 150     399
# 210     590
# 665     549
# 399     369
# Name: Selling Price, Length: 500, dtype: int64

# %%
x_test
# Out:
#                                                  Model    Company      Color  \
# 198      Boult Audio AirBass Combuds Bluetooth Headset      Boult      White
# 351  DigiClues S109 Single Wireless 18 Hours of Cal...  DigiClues      Black
# 157  boAt Rockerz 450 with Upto 15 Hours Playback B...       boAt  Aqua Blue
# 69   Aroma NB119 Advance - 40 Hours Playtime Blueto...      Aroma     Yellow
# 356  DIZO by realme TechLife GoPods D with Enviornm...       DIZO      Black
# ..                                                 ...        ...        ...
# 725  RPM Euro Games Gaming Earphones Headphones For...        RPM       Blue
# 202  Boult Audio ProBass Curve Neckband Bluetooth H...      Boult      Black
# 340  DigiClues Smart HD Sound Earphone with Chargin...  DigiClues      White
# 317             Cosmic Byte GS430 Wired Gaming Headset     Cosmic      Green
# 52   Aroma NB120B Dhoom - 28 Hours Playtime Bluetoo...      Aroma      Black
#
# ...

# %%
y_test
# Out:
# 198    1299
# 351     599
# 157    1499
# 69      533
# 356     999
#        ...
# 725     699
# 202     999
# 340     649
# 317     929
# 52      379
# Name: Selling Price, Length: 500, dtype: int64
